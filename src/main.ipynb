# %%
using Pkg
Pkg.activate("../")
# Out:
#   Activating project at `/workspaces/juliasandbox`

# %%
Pkg.add("Plots")
# Out:
#     Updating registry at `/opt/julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `/workspaces/juliasandbox/Project.toml`
#   No Changes to `/workspaces/juliasandbox/Manifest.toml`

# %%
using Plots
plot(1:100)
